# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Birdsong data

# %%
bird_song_classical_ll = [0.6845085368318072, 0.5468941214731184, 0.3103574487870022, 0.2444557128316265, 0.21562132706581535, 0.19953008457008053, 0.20342433383151637, 0.1867632718788365, 0.180046167887621, 0.1596094602561098, 0.15881646383490602, 0.14724372554633577, 0.1377289674355317, 0.1528748580080978, 0.1184149282684518]

bird_song_quantum_ll = [0.9518752997204408, 0.7813223095263465, 0.7134585229016966, 0.6854195897862062, 0.6703466722520731, 0.6495926713539382, 0.6254575939501746, 0.608799626261501, 0.5964752486196615, 0.577032231678397, 0.559698154360561, 0.5442236075967045, 0.5245351508512335, 0.5039926242020171, 0.4797930131524296]

# %%
plt.plot(bird_song_classical_ll, label='Cross Entropy Loss - Classical')
plt.plot(bird_song_quantum_ll, label='Cross Entropy Loss - Quantum')

plt.xlabel('Training Iterations')
plt.ylabel('Cross Entropy Loss')
# plt.title('Comparison of Cross Entropy Loss between Classical and Quantum Models')
plt.legend()

plt.show()

# %%
bird_song_classical_al = [0.5734190940856934, 0.7416934370994568, 0.8708467483520508, 0.9035369753837585, 0.9185423254966736, 0.92497318983078, 0.9265809059143066, 0.92497318983078, 0.9346194863319397, 0.9362272024154663, 0.9356912970542908, 0.9496248364448547, 0.9464094042778015, 0.9394426345825195, 0.9581993818283081]

bird_song_quantum_al = [0.5391210913658142, 0.5391210913658142, 0.5391210913658142, 0.5391210913658142, 0.5391210913658142, 0.5391210913658142, 0.6907824277877808, 0.8649517893791199, 0.8762058019638062, 0.9126473665237427, 0.9126473665237427, 0.9153268933296204, 0.9233654737472534, 0.9346194863319397, 0.9330117702484131]

# %%
plt.plot(bird_song_classical_al, label='Accuracy - Classical')
plt.plot(bird_song_quantum_al, label='Accuracy - Quantum')

plt.xlabel('Training Iterations')
plt.ylabel('Accuracy')
# plt.title('Comparison of Accuracy between Classical and Quantum Models')
plt.legend()

plt.show()

# %% [markdown]
# # Music Data

# %%
music_classical_ll = [0.7582,0.7377,0.7152,0.7075,0.6926,0.6991,0.6954,0.6975,0.6902,0.6982,0.6918,0.6882,0.6851,0.6901,0.6986,0.6946,0.6868,0.6914,0.6901,0.6799,0.6863,0.6836,0.6800,0.6839,0.6722,0.6735,0.6776,0.6641,0.6604,0.6449,0.6392,0.6159,0.5953,0.5396,0.4966,0.4188,0.3851,0.3151,0.2389,0.2984,0.2290,0.1831,0.2129,0.1436,0.1319,0.1552,0.1288,0.1420,0.1119,0.1090]

music_quantum_ll = [0.7501285642385482, 0.7420000195503235, 0.7350989401340484, 0.7271121978759766, 0.7213417291641235, 0.7148424565792084, 0.7109243929386139, 0.707480525970459, 0.7047552287578582, 0.7018734633922576, 0.7000696301460266, 0.6998764932155609, 0.6977862596511841, 0.6970855712890625, 0.6951175272464752, 0.6954424202442169, 0.6949280977249146, 0.6942545235157013, 0.6932586848735809, 0.6910274744033813, 0.6902457714080811, 0.6895155429840087, 0.6884365737438202, 0.6894496858119965, 0.6907045125961304, 0.6885098099708558, 0.6849005162715912, 0.684163224697113, 0.6832688450813293, 0.68123939037323, 0.681904411315918, 0.6802009999752044, 0.6779336750507354, 0.6739838182926178, 0.6714484572410584, 0.6717334806919097, 0.671429979801178, 0.6679560244083405, 0.6631919622421265, 0.6613588392734527, 0.6541881382465362, 0.65670725107193, 0.6510005593299866, 0.6439887702465057, 0.6397746980190278, 0.6342331767082214, 0.6327316999435425, 0.6262505888938904, 0.6199368834495544, 0.6174967527389527]

# %%
plt.plot(music_classical_ll, label='Cross Entropy Loss - Classical')
plt.plot(music_quantum_ll, label='Cross Entropy Loss - Quantum')

plt.xlabel('Training Iterations')
plt.ylabel('Cross Entropy Loss')
# plt.title('Comparison of Cross Entropy Loss between Classical and Quantum Models')
plt.legend()

plt.show()

# %%
music_classical_al = [0.5,0.5,0.5,0.4937500059604645,0.518750011920929,0.45625001192092896,0.5,0.45625001192092896,0.5687500238418579,0.4937500059604645,0.5062500238418579,0.543749988079071,0.625,0.5,0.4375,0.48750001192092896,0.581250011920929,0.543749988079071,0.550000011920929,0.5874999761581421,0.543749988079071,0.5249999761581421,0.59375,0.581250011920929,0.668749988079071,0.6312500238418579,0.5687500238418579,0.65625,0.675000011920929,0.7250000238418579,0.7124999761581421,0.731249988079071,0.7875000238418579,0.887499988079071,0.875,0.856249988079071,0.8500000238418579,0.893750011920929,0.949999988079071,0.925000011920929,0.9125000238418579,0.9624999761581421,0.9312499761581421,0.949999988079071,0.956250011920929,0.9624999761581421,0.9750000238418579,0.9624999761581421,0.9750000238418579,0.96875]

music_quantum_al = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.512499988079071, 0.59375, 0.699999988079071, 0.762499988079071, 0.7250000238418579, 0.7749999761581421, 0.800000011920929, 0.7875000238418579, 0.7749999761581421, 0.8374999761581421, 0.875, 0.875, 0.9125000238418579, 0.887499988079071, 0.9125000238418579, 0.9375, 0.9437500238418579, 0.96875, 0.9624999761581421, 0.949999988079071, 0.981249988079071, 0.9624999761581421]

# %%
plt.plot(music_classical_al, label='Accuracy - Classical')
plt.plot(music_quantum_al, label='Accuracy - Quantum')

plt.xlabel('Training Iterations')
plt.ylabel('Accuracy')
# plt.title('Comparison of Accuracy between Classical and Quantum Models')
plt.legend()

plt.show()

# %%
X = ['Music Data Classical Model','Music Data Quantum Model','Bird Song Data Classical Model','Bird Song Data Quantum Model'] 
train = [0.987500011920929,0.981249988079071,0.956055760383606,0.9523044228553772] 
test = [0.925000011920929,0.875,0.9288793206214905,0.9504310488700867] 
  
X_axis = np.arange(len(X)) 
plt.figure(figsize=(15, 8))
  
plt.bar(X_axis - 0.2, train, 0.4, label = 'train') 
plt.bar(X_axis + 0.2, test, 0.4, label = 'test') 
  
plt.xticks(X_axis, X, rotation=20, fontsize=14) 
plt.ylabel("Accuracy", fontsize=14) 
plt.legend(loc='lower right', fontsize=14) 
plt.show()

# %%
X = ['Music Data Classical Model','Music Data Quantum Model','Bird Song Data Classical Model','Bird Song Data Quantum Model'] 
train = [0.028718404471874237, 0.6087839007377625, 0.19658777117729187, 0.5529411435127258] 
test = [0.013743416406214237, 0.6271018981933594, 0.0005485698929987848, 0.4276125431060791] 
  
X_axis = np.arange(len(X)) 
plt.figure(figsize=(15, 8))
  
plt.bar(X_axis - 0.2, train, 0.4, label = 'train') 
plt.bar(X_axis + 0.2, test, 0.4, label = 'test') 
  
plt.xticks(X_axis, X, rotation=20, fontsize=14) 
plt.ylabel("Loss", fontsize=14) 
plt.legend(loc='lower right', fontsize=14) 
plt.show()
