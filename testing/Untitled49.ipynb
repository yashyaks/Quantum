# %%
# !pip install qiskit
# Out:
# Requirement already satisfied: qiskit in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (1.0.2)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit) (0.14.2)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit) (1.12.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit) (1.12)
# Requirement already satisfied: dill>=0.3 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit) (5.2.0)
# Requirement already satisfied: typing-extensions in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit) (4.10.0)
# Requirement already satisfied: symengine>=0.11 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from python-dateutil>=2.8.0->qiskit) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from stevedore>=3.0.0->qiskit) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from sympy>=1.3->qiskit) (1.3.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install qiskit-machine-learning
# Out:
# Requirement already satisfied: qiskit-machine-learning in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (0.7.2)
# Requirement already satisfied: qiskit>=0.44 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit-machine-learning) (1.0.2)
# Requirement already satisfied: qiskit-algorithms>=0.2.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit-machine-learning) (0.3.0)
# Requirement already satisfied: scipy>=1.4 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit-machine-learning) (1.12.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit-machine-learning) (1.26.4)
# Requirement already satisfied: psutil>=5 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit-machine-learning) (5.9.8)
# Requirement already satisfied: scikit-learn>=1.2.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit-machine-learning) (1.4.1.post1)
# Requirement already satisfied: fastdtw in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit-machine-learning) (0.3.4)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit-machine-learning) (65.5.0)
# Requirement already satisfied: dill>=0.3.4 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit-machine-learning) (0.3.8)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit>=0.44->qiskit-machine-learning) (0.14.2)
# Requirement already satisfied: sympy>=1.3 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit>=0.44->qiskit-machine-learning) (1.12)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit>=0.44->qiskit-machine-learning) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit>=0.44->qiskit-machine-learning) (5.2.0)
# Requirement already satisfied: typing-extensions in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit>=0.44->qiskit-machine-learning) (4.10.0)
# Requirement already satisfied: symengine>=0.11 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from qiskit>=0.44->qiskit-machine-learning) (0.11.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from scikit-learn>=1.2.0->qiskit-machine-learning) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from scikit-learn>=1.2.0->qiskit-machine-learning) (3.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from python-dateutil>=2.8.0->qiskit>=0.44->qiskit-machine-learning) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from stevedore>=3.0.0->qiskit>=0.44->qiskit-machine-learning) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\djsce.student\downloads\hybridquantum\env\lib\site-packages (from sympy>=1.3->qiskit>=0.44->qiskit-machine-learning) (1.3.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import zipfile

# Path to the zip files containing your dataset
zip_files = ["label1.zip"]

# Directory to extract the contents of the zip files
extracted_dir = "./content/label1/"

# Create the directory if it doesn't exist
os.makedirs(extracted_dir, exist_ok=True)

# Extract zip files
for zip_file in zip_files:
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(extracted_dir)

# %%
import os
import zipfile

# Path to the zip files containing your dataset
zip_files = ["label3.zip"]

# Directory to extract the contents of the zip files
extracted_dir = "./content/label3/"

# Create the directory if it doesn't exist
os.makedirs(extracted_dir, exist_ok=True)


# Extract zip files
for zip_file in zip_files:
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(extracted_dir)

# %%
# !rm -R 'sample_data' '/content/label1.zip' '/content/label3.zip' '.config'

# %%
# Additional torch-related imports
import torch
from torch import cat, no_grad, manual_seed
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torch.optim as optim
from torch.nn import (
    Module,
    Conv2d,
    Linear,
    Dropout2d,
    NLLLoss,
    MaxPool2d,
    Flatten,
    Sequential,
    ReLU,
)
import torch.nn.functional as F
import numpy as np

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Set random seed for reproducibility
torch.manual_seed(42)

batch_size = 32  # Adjust according to your requirements
data_root = "./content/"  # Path to your custom dataset root directory

# Define transformations to be applied to the images
data_transform = transforms.Compose([
    transforms.Resize((223, 217)),  # Resize images to a standard size
    transforms.ToTensor(),           # Convert images to PyTorch tensors
    #transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # Normalize pixel values
])

# Load the custom dataset
custom_dataset = datasets.ImageFolder(root=data_root, transform=data_transform)

# Split the dataset into train and test
# You can define a custom train/test split or use the whole dataset for training
# Here, I'm using the same dataset for both training and testing, but you can split it differently if needed.
train_dataset = custom_dataset

# Define data loaders for train and test datasets
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Check the length of the dataset
print("Number of training samples:", len(train_dataset))
# Out:
# Number of training samples: 1862

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Set random seed for reproducibility
torch.manual_seed(42)

batch_size = 32  # Adjust according to your requirements
data_root = "./test/"  # Path to your custom dataset root directory

# Define transformations to be applied to the images
data_transform = transforms.Compose([
    transforms.Resize((223, 217)),  # Resize images to a standard size
    transforms.ToTensor(),           # Convert images to PyTorch tensors
    #transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # Normalize pixel values
])

# Load the custom dataset
custom_dataset = datasets.ImageFolder(root=data_root, transform=data_transform)

# Split the dataset into train and test
# You can define a custom train/test split or use the whole dataset for training
# Here, I'm using the same dataset for both training and testing, but you can split it differently if needed.
test_dataset = custom_dataset

# Define data loaders for train and test datasets
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)  # No need to shuffle test data

# Check the length of the dataset
print("Number of test samples:", len(test_dataset))
# Out:
# Number of test samples: 138

# %%
import  matplotlib.pyplot as plt

# %%
n_samples_show = 6

data_iter = iter(train_loader)
fig, axes = plt.subplots(nrows=1, ncols=n_samples_show, figsize=(10, 3))

while n_samples_show > 0:
    images, targets = data_iter.__next__()

    axes[n_samples_show - 1].imshow(images[0, 0].numpy())
    axes[n_samples_show - 1].set_xticks([])
    axes[n_samples_show - 1].set_yticks([])
    axes[n_samples_show - 1].set_title("Labeled: {}".format(targets[0].item()))

    n_samples_show -= 1

# %%
# Necessary imports

import numpy as np
import matplotlib.pyplot as plt

from torch import Tensor
from torch.nn import Linear, CrossEntropyLoss, MSELoss
from torch.optim import LBFGS

from qiskit import QuantumCircuit
from qiskit.circuit import Parameter
from qiskit.circuit.library import RealAmplitudes, ZZFeatureMap
from qiskit_algorithms.utils import algorithm_globals
from qiskit_machine_learning.neural_networks import SamplerQNN, EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector

# Set seed for random generators
algorithm_globals.random_seed = 42

# %%
# Define and create QNN
def create_qnn():
    feature_map = ZZFeatureMap(2, reps=5)
    ansatz = RealAmplitudes(2, reps=5)
    qc = QuantumCircuit(3)
    qc.compose(feature_map, inplace=True)
    qc.compose(ansatz, inplace=True)

    # REMEMBER TO SET input_gradients=True FOR ENABLING HYBRID GRADIENT BACKPROP
    qnn = EstimatorQNN(
        circuit=qc,
        input_params=feature_map.parameters,
        weight_params=ansatz.parameters,
        input_gradients=True,
    )
    return qnn


qnn4 = create_qnn()

# %%
# Define torch NN module

class Net(Module):
    def __init__(self, qnn):
        super().__init__()
        self.conv1 = Conv2d(3, 2, kernel_size=5)
        self.conv2 = Conv2d(2, 16, kernel_size=5)
        self.dropout = Dropout2d()
        self.fc1 = Linear(42432, 64)  # Adjust the input size to match the flattened output size
        self.fc2 = Linear(64, 2)  # 2-dimensional input to QNN
        self.qnn = TorchConnector(qnn)  # Apply torch connector, weights chosen
        self.fc3 = Linear(1, 1)  # 1-dimensional output from QNN

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = self.dropout(x)
        x = x.view(x.size(0), -1)  # Flatten the tensor
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        x = self.qnn(x)  # apply QNN
        x = self.fc3(x)
        return torch.cat((x, 1 - x), -1)


model4 = Net(qnn4)

# %%
# Define model, optimizer, and loss function
optimizer = optim.Adam(model4.parameters(), lr=0.0001)
loss_func = NLLLoss()

# Start training
epochs = 20  # Set number of epochs
loss_list = []  # Store loss history
model4.train()  # Set model to training mode

for epoch in range(epochs):
    total_loss = []
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad(set_to_none=True)  # Initialize gradient
        output = model4(data)  # Forward pass
        loss = loss_func(output, target)  # Calculate loss
        loss.backward()  # Backward pass
        optimizer.step()  # Optimize weights
        total_loss.append(loss.item())  # Store loss
    loss_list.append(sum(total_loss) / len(total_loss))
    print("Training [{:.0f}%]\tLoss: {:.4f}".format(100.0 * (epoch + 1) / epochs, loss_list[-1]))
# Out:
# Training [5%]	Loss: -0.5090
# Training [10%]	Loss: -0.5487
# Training [15%]	Loss: -0.5572
# Training [20%]	Loss: -0.5843
# Training [25%]	Loss: -0.6233
# Training [30%]	Loss: -0.6846
# Training [35%]	Loss: -0.7235
# Training [40%]	Loss: -0.7855
# Training [45%]	Loss: -0.8076
# Training [50%]	Loss: -0.7929
# Training [55%]	Loss: -0.8926
# Training [60%]	Loss: -0.9104
# Training [65%]	Loss: -0.9340
# Training [70%]	Loss: -0.9769
# Training [75%]	Loss: -0.9728
# Training [80%]	Loss: -0.9922
# Training [85%]	Loss: -1.0114
# Training [90%]	Loss: -1.0185
# Training [95%]	Loss: -1.0502
# Training [100%]	Loss: -1.0489

# %%
# Plot loss convergence
plt.plot(loss_list)
plt.title("Hybrid NN Training Convergence")
plt.xlabel("Training Iterations")
plt.ylabel("Neg. Log Likelihood Loss")
plt.show()

# %%
model4.eval()  # set model to evaluation mode
with no_grad():

    correct = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        output = model4(data)
        if len(output.shape) == 1:
            output = output.reshape(1, *output.shape)

        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()

        loss = loss_func(output, target)
        total_loss.append(loss.item())

    print(
        "Performance on test data:\n\tLoss: {:.4f}\n\tAccuracy: {:.1f}%".format(
            sum(total_loss) / len(total_loss), correct / len(test_loader) / batch_size * 100
        )
    )
# Out:
# Performance on test data:
# 	Loss: -1.0235
# 	Accuracy: 67.5%

# %%
model4.eval()  # set model to evaluation mode
with no_grad():

    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        output = model4(data)
        if len(output.shape) == 1:
            output = output.reshape(1, *output.shape)

        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()

        loss = loss_func(output, target)
        total_loss.append(loss.item())

    print(
        "Performance on train data:\n\tLoss: {:.4f}\n\tAccuracy: {:.1f}%".format(
            sum(total_loss) / len(total_loss), correct / len(train_loader) / batch_size * 100
        )
    )
# Out:
# Performance on train data:
# 	Loss: -0.9053
# 	Accuracy: 81.6%
