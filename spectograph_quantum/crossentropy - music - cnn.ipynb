# %%
# Additional torch-related imports
import torch
from torch import cat, no_grad, manual_seed
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torch.optim as optim
from torch.nn import (
    Module,
    Conv2d,
    Linear,
    Dropout2d,
    NLLLoss,
    MaxPool2d,
    Flatten,
    Sequential,
    ReLU,
    BCELoss,
    CrossEntropyLoss
)
import torch.nn.functional as F
import numpy as np

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Set random seed for reproducibility
torch.manual_seed(42)

batch_size = 32  # 32 was working nice | Adjust according to your requirements
data_root = "./music/"  # Path to your custom dataset root directory

# Define transformations to be applied to the images
data_transform = transforms.Compose([
    #transforms.Resize((400, 1000)),  # Resize images to a standard size
    transforms.ToTensor(),           # Convert images to PyTorch tensors
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # Normalize pixel values
])

# Load the custom dataset
custom_dataset = datasets.ImageFolder(root=data_root, transform=data_transform)

# Split the dataset into train and test
# You can define a custom train/test split or use the whole dataset for training
# Here, I'm using the same dataset for both training and testing, but you can split it differently if needed.
train_dataset = custom_dataset

# Define data loaders for train and test datasets
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Check the length of the dataset
print("Number of training samples:", len(train_dataset))
# Out:
# Number of training samples: 160

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Set random seed for reproducibility
torch.manual_seed(42)

batch_size = 32  # Adjust according to your requirements
data_root = "./music_test/"  # Path to your custom dataset root directory

# Define transformations to be applied to the images
data_transform = transforms.Compose([
    #transforms.Resize((400, 1000)),  # Resize images to a standard size
    transforms.ToTensor(),           # Convert images to PyTorch tensors
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # Normalize pixel values
])

# Load the custom dataset
custom_dataset = datasets.ImageFolder(root=data_root, transform=data_transform)

# Split the dataset into train and test
# You can define a custom train/test split or use the whole dataset for training
# Here, I'm using the same dataset for both training and testing, but you can split it differently if needed.
test_dataset = custom_dataset

# Define data loaders for train and test datasets
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)  # No need to shuffle test data

# Check the length of the dataset
print("Number of test samples:", len(test_dataset))
# Out:
# Number of test samples: 40

# %%
import  matplotlib.pyplot as plt

# %%
n_samples_show = 6

data_iter = iter(train_loader)
fig, axes = plt.subplots(nrows=1, ncols=n_samples_show, figsize=(10, 3))

while n_samples_show > 0:
    images, targets = data_iter.__next__()

    axes[n_samples_show - 1].imshow(images[0, 0].numpy())
    axes[n_samples_show - 1].set_xticks([])
    axes[n_samples_show - 1].set_yticks([])
    axes[n_samples_show - 1].set_title("Labeled: {}".format(targets[0].item()))

    n_samples_show -= 1
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[5], line 7
#       4 fig, axes = plt.subplots(nrows=1, ncols=n_samples_show, figsize=(10, 3))
#       6 while n_samples_show > 0:
# ----> 7     images, targets = data_iter.__next__()
#       9     axes[n_samples_show - 1].imshow(images[0, 0].numpy())
#      10     axes[n_samples_show - 1].set_xticks([])
#
# File c:\Users\Yash Thakar\PROGRAMMING\Quantum\env\Lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\Yash Thakar\PROGRAMMING\Quantum\env\Lib\site-packages\torch\utils\data\dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
# --> 674     index = self._next_index()  # may raise StopIteration
#     675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#
# File c:\Users\Yash Thakar\PROGRAMMING\Quantum\env\Lib\site-packages\torch\utils\data\dataloader.py:621, in _BaseDataLoaderIter._next_index(self)
#     620 def _next_index(self):
# --> 621     return next(self._sampler_iter)
#
# StopIteration:

# %%
# Necessary imports

import numpy as np
import matplotlib.pyplot as plt

from torch import Tensor
from torch.nn import Linear, CrossEntropyLoss, MSELoss
from torch.optim import LBFGS

from qiskit import QuantumCircuit
from qiskit.circuit import Parameter
from qiskit.circuit.library import RealAmplitudes, ZZFeatureMap
from qiskit_algorithms.utils import algorithm_globals
from qiskit_machine_learning.neural_networks import SamplerQNN, EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector

# Set seed for random generators
algorithm_globals.random_seed = 42

# %%
# Define and create QNN
def create_qnn():
    feature_map = ZZFeatureMap(2, reps=1) #5 was working nice
    ansatz = RealAmplitudes(2, reps=1)
    qc = QuantumCircuit(2)
    qc.compose(feature_map, inplace=True)
    qc.compose(ansatz, inplace=True)

    # REMEMBER TO SET input_gradients=True FOR ENABLING HYBRID GRADIENT BACKPROP
    qnn = EstimatorQNN(
        circuit=qc,
        input_params=feature_map.parameters,
        weight_params=ansatz.parameters,
        input_gradients=True,
    )
    sampler_qnn = SamplerQNN(
    circuit=qc,
    input_params=feature_map.parameters,
    weight_params=ansatz.parameters,
    input_gradients=True,
)

    return sampler_qnn


qnn4 = create_qnn()

# %%
# Define torch NN module

class Net(Module):
    def __init__(self):
        super().__init__()
        self.conv1 = Conv2d(3, 2, kernel_size=5)
        self.conv2 = Conv2d(2, 16, kernel_size=5)
        self.conv3 = Conv2d(16, 64, kernel_size=5)
        #self.dropout = Dropout2d()
        self.fc1 = Linear(102400, 64)  # Adjust the input size to match the flattened output size
        self.fc2 = Linear(64, 1)  # 2-dimensional input to QNN
        #self.qnn = TorchConnector(qnn)  # Apply torch connector, weights chosen
        # self.fc3 = Linear(2, 1)  # 1-dimensional output from QNN

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2)
        #x = self.dropout(x)
        x = x.view(x.size(0), -1)  # Flatten the tensor
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        #x = self.qnn(x)  # apply QNN
        #x = self.fc3(x)
        return torch.cat((x, 1 - x), -1)

model4 = Net()

# %%
# Define model, optimizer, and loss function
optimizer = optim.SGD(model4.parameters(), lr=0.001, momentum=0.9)

#optimizer = optim.Adam(model4.parameters(), lr=0.1)
loss_func = CrossEntropyLoss()

# Start training
epochs = 50  # Set number of epochs
loss_list = []  # Store loss history
model4.train()  # Set model to training mode

for epoch in range(epochs):
    total_loss = []
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad(set_to_none=True)  # Initialize gradient
        output = model4(data)  # Forward pass
        loss = loss_func(output, target)  # Calculate loss
        print(loss)
        loss.backward()  # Backward pass
        optimizer.step()  # Optimize weights
        total_loss.append(loss.item())  # Store loss
    loss_list.append(sum(total_loss) / len(total_loss))
    print("Training [{:.0f}%]\tLoss: {:.4f}".format(100.0 * (epoch + 1) / epochs, loss_list[-1]))
# Out:
# tensor(0.9101, grad_fn=<NllLossBackward0>)
# tensor(0.7348, grad_fn=<NllLossBackward0>)
# tensor(0.6789, grad_fn=<NllLossBackward0>)
# tensor(0.7399, grad_fn=<NllLossBackward0>)
# tensor(0.6819, grad_fn=<NllLossBackward0>)
# Training [2%]	Loss: 0.7491
# tensor(0.6939, grad_fn=<NllLossBackward0>)
# tensor(0.6934, grad_fn=<NllLossBackward0>)
# tensor(0.7221, grad_fn=<NllLossBackward0>)
# tensor(0.7140, grad_fn=<NllLossBackward0>)
# tensor(0.6782, grad_fn=<NllLossBackward0>)
# Training [4%]	Loss: 0.7003
# tensor(0.7510, grad_fn=<NllLossBackward0>)
# tensor(0.6897, grad_fn=<NllLossBackward0>)
# tensor(0.6819, grad_fn=<NllLossBackward0>)
# tensor(0.6855, grad_fn=<NllLossBackward0>)
# tensor(0.6890, grad_fn=<NllLossBackward0>)
# Training [6%]	Loss: 0.6994
# tensor(0.6717, grad_fn=<NllLossBackward0>)
# tensor(0.7133, grad_fn=<NllLossBackward0>)
# tensor(0.6773, grad_fn=<NllLossBackward0>)
# tensor(0.6844, grad_fn=<NllLossBackward0>)
# tensor(0.6896, grad_fn=<NllLossBackward0>)
# Training [8%]	Loss: 0.6873
# tensor(0.6759, grad_fn=<NllLossBackward0>)
# tensor(0.6884, grad_fn=<NllLossBackward0>)
# tensor(0.6787, grad_fn=<NllLossBackward0>)
# tensor(0.6830, grad_fn=<NllLossBackward0>)
# tensor(0.6830, grad_fn=<NllLossBackward0>)
# Training [10%]	Loss: 0.6818
# tensor(0.6945, grad_fn=<NllLossBackward0>)
# tensor(0.6738, grad_fn=<NllLossBackward0>)
# tensor(0.6734, grad_fn=<NllLossBackward0>)
# tensor(0.6738, grad_fn=<NllLossBackward0>)
# tensor(0.6706, grad_fn=<NllLossBackward0>)
# Training [12%]	Loss: 0.6772
# tensor(0.6721, grad_fn=<NllLossBackward0>)
# tensor(0.6728, grad_fn=<NllLossBackward0>)
# tensor(0.6657, grad_fn=<NllLossBackward0>)
# tensor(0.6809, grad_fn=<NllLossBackward0>)
# tensor(0.6685, grad_fn=<NllLossBackward0>)
# Training [14%]	Loss: 0.6720
# tensor(0.6703, grad_fn=<NllLossBackward0>)
# tensor(0.6706, grad_fn=<NllLossBackward0>)
# tensor(0.6637, grad_fn=<NllLossBackward0>)
# tensor(0.6641, grad_fn=<NllLossBackward0>)
# tensor(0.6617, grad_fn=<NllLossBackward0>)
# Training [16%]	Loss: 0.6661
# tensor(0.6536, grad_fn=<NllLossBackward0>)
# tensor(0.6719, grad_fn=<NllLossBackward0>)
# tensor(0.6562, grad_fn=<NllLossBackward0>)
# tensor(0.6726, grad_fn=<NllLossBackward0>)
# tensor(0.6543, grad_fn=<NllLossBackward0>)
# Training [18%]	Loss: 0.6617
# tensor(0.6550, grad_fn=<NllLossBackward0>)
# tensor(0.6608, grad_fn=<NllLossBackward0>)
# tensor(0.6650, grad_fn=<NllLossBackward0>)
# tensor(0.6339, grad_fn=<NllLossBackward0>)
# tensor(0.6962, grad_fn=<NllLossBackward0>)
# Training [20%]	Loss: 0.6622
# tensor(0.6463, grad_fn=<NllLossBackward0>)
# tensor(0.6334, grad_fn=<NllLossBackward0>)
# tensor(0.6509, grad_fn=<NllLossBackward0>)
# tensor(0.6405, grad_fn=<NllLossBackward0>)
# tensor(0.6405, grad_fn=<NllLossBackward0>)
# Training [22%]	Loss: 0.6423
# tensor(0.6461, grad_fn=<NllLossBackward0>)
# tensor(0.6246, grad_fn=<NllLossBackward0>)
# tensor(0.6296, grad_fn=<NllLossBackward0>)
# tensor(0.6417, grad_fn=<NllLossBackward0>)
# tensor(0.6387, grad_fn=<NllLossBackward0>)
# Training [24%]	Loss: 0.6362
# tensor(0.6234, grad_fn=<NllLossBackward0>)
# tensor(0.6157, grad_fn=<NllLossBackward0>)
# tensor(0.6240, grad_fn=<NllLossBackward0>)
# tensor(0.6573, grad_fn=<NllLossBackward0>)
# tensor(0.6499, grad_fn=<NllLossBackward0>)
# Training [26%]	Loss: 0.6340
# tensor(0.6382, grad_fn=<NllLossBackward0>)
# tensor(0.6143, grad_fn=<NllLossBackward0>)
# tensor(0.6082, grad_fn=<NllLossBackward0>)
# tensor(0.6488, grad_fn=<NllLossBackward0>)
# tensor(0.5875, grad_fn=<NllLossBackward0>)
# Training [28%]	Loss: 0.6194
# tensor(0.6195, grad_fn=<NllLossBackward0>)
# tensor(0.6000, grad_fn=<NllLossBackward0>)
# tensor(0.6178, grad_fn=<NllLossBackward0>)
# tensor(0.6317, grad_fn=<NllLossBackward0>)
# tensor(0.6198, grad_fn=<NllLossBackward0>)
# Training [30%]	Loss: 0.6178
# tensor(0.5730, grad_fn=<NllLossBackward0>)
# tensor(0.5454, grad_fn=<NllLossBackward0>)
# tensor(0.6372, grad_fn=<NllLossBackward0>)
# tensor(0.6461, grad_fn=<NllLossBackward0>)
# tensor(0.6858, grad_fn=<NllLossBackward0>)
# Training [32%]	Loss: 0.6175
# tensor(0.5479, grad_fn=<NllLossBackward0>)
# tensor(0.5428, grad_fn=<NllLossBackward0>)
# tensor(0.5543, grad_fn=<NllLossBackward0>)
# tensor(0.5401, grad_fn=<NllLossBackward0>)
# tensor(0.5430, grad_fn=<NllLossBackward0>)
# Training [34%]	Loss: 0.5456
# tensor(0.5188, grad_fn=<NllLossBackward0>)
# tensor(0.4974, grad_fn=<NllLossBackward0>)
# tensor(0.5075, grad_fn=<NllLossBackward0>)
# tensor(0.5779, grad_fn=<NllLossBackward0>)
# tensor(0.5179, grad_fn=<NllLossBackward0>)
# Training [36%]	Loss: 0.5239
# tensor(0.4993, grad_fn=<NllLossBackward0>)
# tensor(0.5234, grad_fn=<NllLossBackward0>)
# tensor(0.4890, grad_fn=<NllLossBackward0>)
# tensor(0.4424, grad_fn=<NllLossBackward0>)
# tensor(0.5079, grad_fn=<NllLossBackward0>)
# Training [38%]	Loss: 0.4924
# tensor(0.4651, grad_fn=<NllLossBackward0>)
# tensor(0.4758, grad_fn=<NllLossBackward0>)
# tensor(0.5648, grad_fn=<NllLossBackward0>)
# tensor(0.4403, grad_fn=<NllLossBackward0>)
# tensor(0.4544, grad_fn=<NllLossBackward0>)
# Training [40%]	Loss: 0.4801
# tensor(0.3622, grad_fn=<NllLossBackward0>)
# tensor(0.4170, grad_fn=<NllLossBackward0>)
# tensor(0.4821, grad_fn=<NllLossBackward0>)
# tensor(0.3833, grad_fn=<NllLossBackward0>)
# tensor(0.4658, grad_fn=<NllLossBackward0>)
# Training [42%]	Loss: 0.4221
# tensor(0.2629, grad_fn=<NllLossBackward0>)
# tensor(0.5333, grad_fn=<NllLossBackward0>)
# tensor(0.4717, grad_fn=<NllLossBackward0>)
# tensor(0.2869, grad_fn=<NllLossBackward0>)
# tensor(0.4192, grad_fn=<NllLossBackward0>)
# Training [44%]	Loss: 0.3948
# tensor(0.3968, grad_fn=<NllLossBackward0>)
# tensor(0.3035, grad_fn=<NllLossBackward0>)
# tensor(0.3972, grad_fn=<NllLossBackward0>)
# tensor(0.4605, grad_fn=<NllLossBackward0>)
# tensor(0.3059, grad_fn=<NllLossBackward0>)
# Training [46%]	Loss: 0.3728
# tensor(0.2727, grad_fn=<NllLossBackward0>)
# tensor(0.3242, grad_fn=<NllLossBackward0>)
# tensor(0.3108, grad_fn=<NllLossBackward0>)
# tensor(0.4182, grad_fn=<NllLossBackward0>)
# tensor(0.2473, grad_fn=<NllLossBackward0>)
# Training [48%]	Loss: 0.3147
# tensor(0.1856, grad_fn=<NllLossBackward0>)
# tensor(0.2520, grad_fn=<NllLossBackward0>)
# tensor(0.2887, grad_fn=<NllLossBackward0>)
# tensor(0.3595, grad_fn=<NllLossBackward0>)
# tensor(0.2400, grad_fn=<NllLossBackward0>)
# Training [50%]	Loss: 0.2652
# tensor(0.4022, grad_fn=<NllLossBackward0>)
# tensor(0.2011, grad_fn=<NllLossBackward0>)
# tensor(0.1372, grad_fn=<NllLossBackward0>)
# tensor(0.3702, grad_fn=<NllLossBackward0>)
# tensor(0.2017, grad_fn=<NllLossBackward0>)
# Training [52%]	Loss: 0.2625
# tensor(0.4712, grad_fn=<NllLossBackward0>)
# tensor(0.1882, grad_fn=<NllLossBackward0>)
# tensor(0.2406, grad_fn=<NllLossBackward0>)
# tensor(0.2856, grad_fn=<NllLossBackward0>)
# tensor(0.1040, grad_fn=<NllLossBackward0>)
# Training [54%]	Loss: 0.2579
# tensor(0.2457, grad_fn=<NllLossBackward0>)
# tensor(0.2744, grad_fn=<NllLossBackward0>)
# tensor(0.1643, grad_fn=<NllLossBackward0>)
# tensor(0.1862, grad_fn=<NllLossBackward0>)
# tensor(0.1259, grad_fn=<NllLossBackward0>)
# Training [56%]	Loss: 0.1993
# tensor(0.2157, grad_fn=<NllLossBackward0>)
# tensor(0.1860, grad_fn=<NllLossBackward0>)
# tensor(0.2666, grad_fn=<NllLossBackward0>)
# tensor(0.1400, grad_fn=<NllLossBackward0>)
# tensor(0.1194, grad_fn=<NllLossBackward0>)
# Training [58%]	Loss: 0.1855
# tensor(0.2119, grad_fn=<NllLossBackward0>)
# tensor(0.1529, grad_fn=<NllLossBackward0>)
# tensor(0.0805, grad_fn=<NllLossBackward0>)
# tensor(0.1574, grad_fn=<NllLossBackward0>)
# tensor(0.2434, grad_fn=<NllLossBackward0>)
# Training [60%]	Loss: 0.1692
# tensor(0.2282, grad_fn=<NllLossBackward0>)
# tensor(0.0760, grad_fn=<NllLossBackward0>)
# tensor(0.1262, grad_fn=<NllLossBackward0>)
# tensor(0.2086, grad_fn=<NllLossBackward0>)
# tensor(0.1506, grad_fn=<NllLossBackward0>)
# Training [62%]	Loss: 0.1579
# tensor(0.3828, grad_fn=<NllLossBackward0>)
# tensor(0.1926, grad_fn=<NllLossBackward0>)
# tensor(0.1029, grad_fn=<NllLossBackward0>)
# tensor(0.0858, grad_fn=<NllLossBackward0>)
# tensor(0.1253, grad_fn=<NllLossBackward0>)
# Training [64%]	Loss: 0.1779
# tensor(0.0745, grad_fn=<NllLossBackward0>)
# tensor(0.1442, grad_fn=<NllLossBackward0>)
# tensor(0.2483, grad_fn=<NllLossBackward0>)
# tensor(0.1352, grad_fn=<NllLossBackward0>)
# tensor(0.2094, grad_fn=<NllLossBackward0>)
# Training [66%]	Loss: 0.1623
# tensor(0.1839, grad_fn=<NllLossBackward0>)
# tensor(0.2129, grad_fn=<NllLossBackward0>)
# tensor(0.1315, grad_fn=<NllLossBackward0>)
# tensor(0.0919, grad_fn=<NllLossBackward0>)
# tensor(0.0971, grad_fn=<NllLossBackward0>)
# Training [68%]	Loss: 0.1434
# tensor(0.0602, grad_fn=<NllLossBackward0>)
# tensor(0.4351, grad_fn=<NllLossBackward0>)
# tensor(0.0920, grad_fn=<NllLossBackward0>)
# tensor(0.0650, grad_fn=<NllLossBackward0>)
# tensor(0.1581, grad_fn=<NllLossBackward0>)
# Training [70%]	Loss: 0.1621
# tensor(0.2135, grad_fn=<NllLossBackward0>)
# tensor(0.1760, grad_fn=<NllLossBackward0>)
# tensor(0.0845, grad_fn=<NllLossBackward0>)
# tensor(0.0477, grad_fn=<NllLossBackward0>)
# tensor(0.3111, grad_fn=<NllLossBackward0>)
# Training [72%]	Loss: 0.1666
# tensor(0.0873, grad_fn=<NllLossBackward0>)
# tensor(0.1406, grad_fn=<NllLossBackward0>)
# tensor(0.0919, grad_fn=<NllLossBackward0>)
# tensor(0.1402, grad_fn=<NllLossBackward0>)
# tensor(0.2910, grad_fn=<NllLossBackward0>)
# Training [74%]	Loss: 0.1502
# tensor(0.2052, grad_fn=<NllLossBackward0>)
# tensor(0.0579, grad_fn=<NllLossBackward0>)
# tensor(0.2232, grad_fn=<NllLossBackward0>)
# tensor(0.1984, grad_fn=<NllLossBackward0>)
# tensor(0.0700, grad_fn=<NllLossBackward0>)
# Training [76%]	Loss: 0.1510
# tensor(0.0906, grad_fn=<NllLossBackward0>)
# tensor(0.1966, grad_fn=<NllLossBackward0>)
# tensor(0.0487, grad_fn=<NllLossBackward0>)
# tensor(0.1835, grad_fn=<NllLossBackward0>)
# tensor(0.1311, grad_fn=<NllLossBackward0>)
# Training [78%]	Loss: 0.1301
# tensor(0.1608, grad_fn=<NllLossBackward0>)
# tensor(0.1829, grad_fn=<NllLossBackward0>)
# tensor(0.0717, grad_fn=<NllLossBackward0>)
# tensor(0.0700, grad_fn=<NllLossBackward0>)
# tensor(0.0590, grad_fn=<NllLossBackward0>)
# Training [80%]	Loss: 0.1089
# tensor(0.0358, grad_fn=<NllLossBackward0>)
# tensor(0.1291, grad_fn=<NllLossBackward0>)
# tensor(0.0804, grad_fn=<NllLossBackward0>)
# tensor(0.0203, grad_fn=<NllLossBackward0>)
# tensor(0.3249, grad_fn=<NllLossBackward0>)
# Training [82%]	Loss: 0.1181
# tensor(0.0743, grad_fn=<NllLossBackward0>)
# tensor(0.0531, grad_fn=<NllLossBackward0>)
# tensor(0.1726, grad_fn=<NllLossBackward0>)
# tensor(0.0962, grad_fn=<NllLossBackward0>)
# tensor(0.1691, grad_fn=<NllLossBackward0>)
# Training [84%]	Loss: 0.1131
# tensor(0.1449, grad_fn=<NllLossBackward0>)
# tensor(0.0487, grad_fn=<NllLossBackward0>)
# tensor(0.0775, grad_fn=<NllLossBackward0>)
# tensor(0.0401, grad_fn=<NllLossBackward0>)
# tensor(0.1711, grad_fn=<NllLossBackward0>)
# Training [86%]	Loss: 0.0965
# tensor(0.0377, grad_fn=<NllLossBackward0>)
# tensor(0.0198, grad_fn=<NllLossBackward0>)
# tensor(0.1987, grad_fn=<NllLossBackward0>)
# tensor(0.1529, grad_fn=<NllLossBackward0>)
# tensor(0.0523, grad_fn=<NllLossBackward0>)
# Training [88%]	Loss: 0.0923
# tensor(0.0434, grad_fn=<NllLossBackward0>)
# tensor(0.1431, grad_fn=<NllLossBackward0>)
# tensor(0.0616, grad_fn=<NllLossBackward0>)
# tensor(0.1592, grad_fn=<NllLossBackward0>)
# tensor(0.0647, grad_fn=<NllLossBackward0>)
# Training [90%]	Loss: 0.0944
# tensor(0.1453, grad_fn=<NllLossBackward0>)
# tensor(0.1697, grad_fn=<NllLossBackward0>)
# tensor(0.0426, grad_fn=<NllLossBackward0>)
# tensor(0.0490, grad_fn=<NllLossBackward0>)
# tensor(0.0262, grad_fn=<NllLossBackward0>)
# Training [92%]	Loss: 0.0866
# tensor(0.0447, grad_fn=<NllLossBackward0>)
# tensor(0.2667, grad_fn=<NllLossBackward0>)
# tensor(0.0477, grad_fn=<NllLossBackward0>)
# tensor(0.0609, grad_fn=<NllLossBackward0>)
# tensor(0.0272, grad_fn=<NllLossBackward0>)
# Training [94%]	Loss: 0.0895
# tensor(0.0306, grad_fn=<NllLossBackward0>)
# tensor(0.0322, grad_fn=<NllLossBackward0>)
# tensor(0.1725, grad_fn=<NllLossBackward0>)
# tensor(0.1313, grad_fn=<NllLossBackward0>)
# tensor(0.0372, grad_fn=<NllLossBackward0>)
# Training [96%]	Loss: 0.0808
# tensor(0.0534, grad_fn=<NllLossBackward0>)
# tensor(0.2115, grad_fn=<NllLossBackward0>)
# tensor(0.0345, grad_fn=<NllLossBackward0>)
# tensor(0.0498, grad_fn=<NllLossBackward0>)
# tensor(0.0437, grad_fn=<NllLossBackward0>)
# Training [98%]	Loss: 0.0786
# tensor(0.0246, grad_fn=<NllLossBackward0>)
# tensor(0.0239, grad_fn=<NllLossBackward0>)
# tensor(0.0648, grad_fn=<NllLossBackward0>)
# tensor(0.1320, grad_fn=<NllLossBackward0>)
# tensor(0.1612, grad_fn=<NllLossBackward0>)
# Training [100%]	Loss: 0.0813

# %%
# Plot loss convergence
plt.plot(loss_list)
plt.title("Hybrid NN Training Convergence")
plt.xlabel("Training Iterations")
plt.ylabel("Cross Entropy Loss")
plt.show()

# %%
model4.eval()  # set model to evaluation mode
with no_grad():

    correct = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        output = model4(data)
        if len(output.shape) == 1:
            output = output.reshape(1, *output.shape)

        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()

        loss = loss_func(output, target)
        total_loss.append(loss.item())

    print(
        "Performance on test data:\n\tLoss: {:.4f}\n\tAccuracy: {:.1f}%".format(
            sum(total_loss) / len(total_loss), correct / len(test_loader) / batch_size * 100
        )
    )
# Out:
# Performance on test data:
# 	Loss: 0.1244
# 	Accuracy: 56.2%

# %%
model4.eval()  # set model to evaluation mode
with no_grad():

    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        output = model4(data)
        if len(output.shape) == 1:
            output = output.reshape(1, *output.shape)

        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()

        loss = loss_func(output, target)
        total_loss.append(loss.item())

    print(
        "Performance on train data:\n\tLoss: {:.4f}\n\tAccuracy: {:.1f}%".format(
            sum(total_loss) / len(total_loss), correct / len(train_loader) / batch_size * 100
        )
    )
# Out:
# Performance on train data:
# 	Loss: 0.1007
# 	Accuracy: 98.8%
